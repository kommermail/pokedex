# %% [markdown]
# <h2 align="center">Multiple Linear Regression</h2>

# %% [markdown]
# Linear Regression is a useful tool for predicting a quantitative response.

# %% [markdown]
# We have an input vector $X^T = (X_1, X_2,...,X_p)$, and want to predict a real-valued output $Y$. The linear regression model has the form

# %% [markdown]
# <h4 align="center"> $f(x) = \beta_0 + \sum_{j=1}^p X_j \beta_j$. </h4>

# %% [markdown]
# The linear model either assumes that the regression function $E(Y|X)$ is linear, or that the linear model is a reasonable approximation.Here the $\beta_j$'s are unknown parameters or coefficients, and the variables $X_j$ can come from different sources. No matter the source of $X_j$, the model is linear in the parameters.

# %% [markdown]
# **Simple Linear Regression**: <h5 align=center>$$Y = \beta_0 + \beta_1 X + \epsilon$$</h5>

# %% [markdown]
# **Multiple Linear Regression**: <h5 align=center>$$Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 +...+ \beta_p X_p + \epsilon$$ </h5>
# <h5 align=center> $$sales = \beta_0 + \beta_1 \times TV + \beta_2 \times radio + \beta_3 \times newspaper + \epsilon$$ </h5>

# %% [markdown]
# ### Task 1: Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import skew
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# ### Task 2: Load the Data

# %% [markdown]
# The adverstiting dataset captures sales revenue generated with respect to advertisement spends across multiple channles like radio, tv and newspaper.

# %%
advert=pd.read_csv('Advertising.csv')
advert.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
advert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# ### Task 3: Relationship between Features and Response

# %%
sns.pairplot(advert, x_vars=['TV','radio','newspaper'], y_vars='sales', height=7, aspect=0.7);

# %% [markdown]
# ### Task 4: Multiple Linear Regression - Estimating Coefficients

# %%
from sklearn.linear_model import LinearRegression

X=advert[['TV', 'radio', 'newspaper']]
y=advert.sales

lm1=LinearRegression()
lm1.fit(X,y)

print(lm1.intercept_)
print(lm1.coef_)
# Out:
# 2.938889369459405
# [ 0.04576465  0.18853002 -0.00103749]

# %%
list(zip(['TV','radio','newspaper'], lm1.coef_))
# Out:
# [('TV', 0.045764645455397636),
#  ('radio', 0.18853001691820437),
#  ('newspaper', -0.001037493042476257)]

# %%
sns.heatmap(advert.corr(), annot=True);

# %% [markdown]
# ### Task 5: Feature Selection

# %%
from sklearn.metrics import r2_score

lm2=LinearRegression().fit(X[['TV','radio']], y)
lm2_pred=lm2.predict(X[['TV','radio']])

print("R^2:", r2_score(y, lm2_pred))
# Out:
# R^2: 0.8971942610828956

# %%
lm3=LinearRegression().fit(X[['TV','radio','newspaper']], y)
lm3_pred=lm3.predict(X[['TV','radio','newspaper']])

print("R^2:", r2_score(y, lm3_pred))
# Out:
# R^2: 0.8972106381789522

# %%
# this r^2 value demonstrates the relationship between the fitted model and the projected sales values(our response variable or y).
# As you can see, there is only a small difference in the r^2 values that include newspaper and those that don't 
# include newspaper.this means that including the newspaper data does not change our r^2 (and thus, our sales) 
# by a significant amount.
# Out:
# R^2: 0.8972106381789522

# %% [markdown]
# ### Task 6: Model Evaluation Using Train/Test Split and Metrics

# %% [markdown]
# **Mean Absolute Error** (MAE) is the mean of the absolute value of the errors: <h5 align=center>$$\frac{1}{n}\sum_{i=1}^{n} \left |y_i - \hat{y_i} \right |$$</h5>
# **Mean Squared Error** (MSE) is the mean of the squared errors: <h5 align=center>$$\frac{1}{n}\sum_{i=1}^{n} (y_i - \hat{y_i})^2$$</h5>
# **Root Mean Squared Error** (RMSE) is the mean of the squared errors: <h5 align=center>$$\sqrt{\frac{1}{n}\sum_{i=1}^{n} (y_i - \hat{y_i})^2}$$</h5>

# %% [markdown]
# Let's use train/test split with RMSE to see whether newspaper should be kept in the model:

# %%
# RMSE calculates the difference between the actual value and the predicted value of the response variable.  And it takes
# the square root of the mean of the square of all the errors.  The smaller the value of an RMSE, the better the model is.
# the RMSE can be interpreted as the standard deviation of the unexplained variance.  it is in the same unit as the response variable.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
X=advert[['TV','radio','newspaper']]
y=advert.sales

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1)

lm4=LinearRegression().fit(X_train, y_train)
lm4_pred=lm4.predict(X_test)

print("RMSE: ", np.sqrt(mean_squared_error(y_test, lm4_pred)))
print("R^2: ",r2_score(y_test, lm4_pred))
# Out:
# RMSE:  1.4046514230328948
# R^2:  0.9156213613792232

# %%
X=advert[['TV','radio']]
y=advert.sales

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1)

lm5=LinearRegression().fit(X_train.values, y_train)
lm5_pred=lm5.predict(X_test.values)

print("RMSE: ", np.sqrt(mean_squared_error(y_test, lm5_pred)))
print("R^2: ",r2_score(y_test, lm5_pred))
# Out:
# RMSE:  1.3879034699382888
# R^2:  0.9176214942248908

# %%
from yellowbrick.regressor import PredictionError, ResidualsPlot

visualizer = PredictionError(lm5).fit(X_train.values, y_train)
visualizer.score(X_test.values, y_test)
visualizer.poof();

# %% [markdown]
# ### Task 7: Interaction Effect (Synergy)

# %%
advert['interaction'] = advert['TV'] * advert['radio']

X= advert[['TV', 'radio', 'interaction']]

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1)

lm6=LinearRegression().fit(X_train.values, y_train)
lm6_pred=lm6.predict(X_test.values)

print("RMSE: ", np.sqrt(mean_squared_error(y_test, lm6_pred)))
print("R^2: ",r2_score(y_test, lm6_pred))
# Out:
# RMSE:  0.7011871137164338
# R^2:  0.978973681468126

# %%
visualizer = PredictionError(lm6).fit(X_train.values, y_train)
visualizer.score(X_test.values, y_test)
visualizer.poof();
