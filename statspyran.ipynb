# %% [markdown]
# # World Bank Science and Technology Data Analysis

# %% [markdown]
# ## Importing the Data

# %%
import pandas as pd

# %%
st_data_2018=pd.read_csv("science_tech_2018.csv")
st_data_2018.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           0.049514
# 2         Algeria                                                NaN
# 3  American Samoa                                                NaN
# 4         Andorra                                          28.460560
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                               591717.0                         3713.0
# 2                                    NaN                         9490.0
# 3                                    NaN                            NaN
# 4                             33913480.0                         1180.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# 1                                    917.0
# 2                                   5469.0
# 3                                      NaN
# 4                                    256.0
#
#    Trademark applications, direct nonresident  Patent applications, residents  \
# 0                                         NaN                             NaN
# 1                                      2796.0                            15.0
# 2                                      4021.0                           152.0
# 3                                         NaN                             NaN
# 4                                       924.0                             1.0
#
#    Patent applications, nonresidents  \
# 0                                NaN
# 1                                3.0
# 2                              521.0
# 3                                NaN
# 4                               10.0
#
#    Scientific and technical journal articles  \
# 0                                     111.72
# 1                                     180.36
# 2                                    5231.44
# 3                                        NaN
# 4                                       3.60
#
#    Research and development expenditure (% of GDP)
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN

# %%
st_data_2018.shape
# Out:
# (219, 10)

# %%
st_data_2018.columns
# Out:
# Index(['Country Name', 'High-technology exports (% of manufactured exports)',
#        'High-technology exports (current US$)',
#        'Trademark applications, total',
#        'Trademark applications, direct resident',
#        'Trademark applications, direct nonresident',
#        'Patent applications, residents', 'Patent applications, nonresidents',
#        'Scientific and technical journal articles',
#        'Research and development expenditure (% of GDP)'],
#       dtype='object')

# %%
st_data_2009=pd.read_csv("science_tech_2009.csv")
st_data_2009.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                           1.328024
# 2         Algeria                                           0.653887
# 3  American Samoa                                                NaN
# 4         Andorra                                          12.192161
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                             10128935.0                         3456.0
# 2                              4616076.0                         5345.0
# 3                                    NaN                            NaN
# 4                             10402350.0                          785.0
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# 1                                    213.0
# 2                                      NaN
# 3                                      NaN
# 4                                    243.0
#
#    Trademark applications, direct nonresident  Patent applications, residents  \
# 0                                         NaN                             NaN
# 1                                      3243.0                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                       542.0                             NaN
#
#    Patent applications, nonresidents  \
# 0                                NaN
# 1                              361.0
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    Scientific and technical journal articles  \
# 0                                      26.30
# 1                                      70.35
# 2                                    2135.32
# 3                                        NaN
# 4                                       2.55
#
#    Research and development expenditure (% of GDP)
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# ### Missing Data

# %%
st_data_2018.isna().sum()
# Out:
# Country Name                                             0
# High-technology exports (% of manufactured exports)     87
# High-technology exports (current US$)                   88
# Trademark applications, total                           86
# Trademark applications, direct resident                 91
# Trademark applications, direct nonresident              90
# Patent applications, residents                         101
# Patent applications, nonresidents                      100
# Scientific and technical journal articles               20
# Research and development expenditure (% of GDP)        146
# dtype: int64

# %%
st_data_2018_clean= st_data_2018.dropna()
st_data_2018_clean.shape
# Out:
# (51, 10)

# %%
st_data_2009_clean=st_data_2009.dropna()
st_data_2009_clean.shape
# Out:
# (56, 10)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Descriptive Statistics

# %%
pd.set_option('display.float_format', lambda x: '%.3f' %x)
st_data_2018_clean.describe().style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a33c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a33c8_level0_col0" class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th id="T_a33c8_level0_col1" class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th id="T_a33c8_level0_col2" class="col_heading level0 col2" >Trademark applications, total</th>
#       <th id="T_a33c8_level0_col3" class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th id="T_a33c8_level0_col4" class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th id="T_a33c8_level0_col5" class="col_heading level0 col5" >Patent applications, residents</th>
#       <th id="T_a33c8_level0_col6" class="col_heading level0 col6" >Patent applications, nonresidents</th>
#       <th id="T_a33c8_level0_col7" class="col_heading level0 col7" >Scientific and technical journal articles</th>
#       <th id="T_a33c8_level0_col8" class="col_heading level0 col8" >Research and development expenditure (% of GDP)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a33c8_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_a33c8_row0_col0" class="data row0 col0" >51</td>
#       <td id="T_a33c8_row0_col1" class="data row0 col1" >51</td>
#       <td id="T_a33c8_row0_col2" class="data row0 col2" >51</td>
#       <td id="T_a33c8_row0_col3" class="data row0 col3" >51</td>
#       <td id="T_a33c8_row0_col4" class="data row0 col4" >51</td>
#       <td id="T_a33c8_row0_col5" class="data row0 col5" >51</td>
#       <td id="T_a33c8_row0_col6" class="data row0 col6" >51</td>
#       <td id="T_a33c8_row0_col7" class="data row0 col7" >51</td>
#       <td id="T_a33c8_row0_col8" class="data row0 col8" >51</td>
#     </tr>
#     <tr>
#       <th id="T_a33c8_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_a33c8_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_a33c8_row1_col1" class="data row1 col1" >25,697,867,097</td>
#       <td id="T_a33c8_row1_col2" class="data row1 col2" >44,515</td>
#       <td id="T_a33c8_row1_col3" class="data row1 col3" >33,921</td>
#       <td id="T_a33c8_row1_col4" class="data row1 col4" >10,594</td>
#       <td id="T_a33c8_row1_col5" class="data row1 col5" >16,828</td>
#       <td id="T_a33c8_row1_col6" class="data row1 col6" >11,187</td>
#       <td id="T_a33c8_row1_col7" class="data row1 col7" >30,499</td>
#       <td id="T_a33c8_row1_col8" class="data row1 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a33c8_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_a33c8_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_a33c8_row2_col1" class="data row2 col1" >48,690,230,336</td>
#       <td id="T_a33c8_row2_col2" class="data row2 col2" >85,394</td>
#       <td id="T_a33c8_row2_col3" class="data row2 col3" >69,219</td>
#       <td id="T_a33c8_row2_col4" class="data row2 col4" >18,797</td>
#       <td id="T_a33c8_row2_col5" class="data row2 col5" >56,775</td>
#       <td id="T_a33c8_row2_col6" class="data row2 col6" >44,725</td>
#       <td id="T_a33c8_row2_col7" class="data row2 col7" >65,091</td>
#       <td id="T_a33c8_row2_col8" class="data row2 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a33c8_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_a33c8_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_a33c8_row3_col1" class="data row3 col1" >115,051</td>
#       <td id="T_a33c8_row3_col2" class="data row3 col2" >1,974</td>
#       <td id="T_a33c8_row3_col3" class="data row3 col3" >141</td>
#       <td id="T_a33c8_row3_col4" class="data row3 col4" >1,008</td>
#       <td id="T_a33c8_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_a33c8_row3_col6" class="data row3 col6" >4</td>
#       <td id="T_a33c8_row3_col7" class="data row3 col7" >127</td>
#       <td id="T_a33c8_row3_col8" class="data row3 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a33c8_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_a33c8_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a33c8_row4_col1" class="data row4 col1" >433,839,196</td>
#       <td id="T_a33c8_row4_col2" class="data row4 col2" >4,203</td>
#       <td id="T_a33c8_row4_col3" class="data row4 col3" >1,858</td>
#       <td id="T_a33c8_row4_col4" class="data row4 col4" >1,937</td>
#       <td id="T_a33c8_row4_col5" class="data row4 col5" >96</td>
#       <td id="T_a33c8_row4_col6" class="data row4 col6" >26</td>
#       <td id="T_a33c8_row4_col7" class="data row4 col7" >1,416</td>
#       <td id="T_a33c8_row4_col8" class="data row4 col8" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a33c8_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_a33c8_row5_col0" class="data row5 col0" >10</td>
#       <td id="T_a33c8_row5_col1" class="data row5 col1" >4,294,542,879</td>
#       <td id="T_a33c8_row5_col2" class="data row5 col2" >10,025</td>
#       <td id="T_a33c8_row5_col3" class="data row5 col3" >4,711</td>
#       <td id="T_a33c8_row5_col4" class="data row5 col4" >3,417</td>
#       <td id="T_a33c8_row5_col5" class="data row5 col5" >678</td>
#       <td id="T_a33c8_row5_col6" class="data row5 col6" >168</td>
#       <td id="T_a33c8_row5_col7" class="data row5 col7" >10,345</td>
#       <td id="T_a33c8_row5_col8" class="data row5 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a33c8_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_a33c8_row6_col0" class="data row6 col0" >17</td>
#       <td id="T_a33c8_row6_col1" class="data row6 col1" >21,254,931,313</td>
#       <td id="T_a33c8_row6_col2" class="data row6 col2" >40,292</td>
#       <td id="T_a33c8_row6_col3" class="data row6 col3" >27,325</td>
#       <td id="T_a33c8_row6_col4" class="data row6 col4" >9,829</td>
#       <td id="T_a33c8_row6_col5" class="data row6 col5" >1,938</td>
#       <td id="T_a33c8_row6_col6" class="data row6 col6" >1,834</td>
#       <td id="T_a33c8_row6_col7" class="data row6 col7" >23,684</td>
#       <td id="T_a33c8_row6_col8" class="data row6 col8" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a33c8_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_a33c8_row7_col0" class="data row7 col0" >36</td>
#       <td id="T_a33c8_row7_col1" class="data row7 col1" >210,082,307,180</td>
#       <td id="T_a33c8_row7_col2" class="data row7 col2" >464,786</td>
#       <td id="T_a33c8_row7_col3" class="data row7 col3" >342,150</td>
#       <td id="T_a33c8_row7_col4" class="data row7 col4" >122,636</td>
#       <td id="T_a33c8_row7_col5" class="data row7 col5" >285,095</td>
#       <td id="T_a33c8_row7_col6" class="data row7 col6" >312,046</td>
#       <td id="T_a33c8_row7_col7" class="data row7 col7" >422,808</td>
#       <td id="T_a33c8_row7_col8" class="data row7 col8" >5</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib  inline

# %%
sns.boxplot(x=st_data_2018_clean['High-technology exports (% of manufactured exports)'])
# Out:
# <Axes: xlabel='High-technology exports (% of manufactured exports)'>

# %%
sns.boxplot(x=st_data_2009_clean['High-technology exports (% of manufactured exports)'])
# Out:
# <Axes: xlabel='High-technology exports (% of manufactured exports)'>

# %% [markdown]
# ## Outliers

# %%
columns=st_data_2018_clean.columns
for i in range(1,len(columns)):
    fig=plt.figure(figsize=(10,5))
    sns.boxplot(x=st_data_2018_clean[columns[i]])

# %%
articles_max=st_data_2018_clean['Scientific and technical journal articles'].max()

# %%
st_data_2018_clean[st_data_2018_clean['Scientific and technical journal articles']==articles_max]
# Out:
#       Country Name  High-technology exports (% of manufactured exports)  \
# 207  United States                                             18.896
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 207                       156365524736.000                     464786.000
#
#      Trademark applications, direct resident  \
# 207                               342150.000
#
#      Trademark applications, direct nonresident  \
# 207                                  122636.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 207                      285095.000                         312046.000
#
#      Scientific and technical journal articles  \
# 207                                 422807.710
#
#      Research and development expenditure (% of GDP)
# 207                                            2.838

# %%
st_data_2018_clean[st_data_2018_clean['Scientific and technical journal articles']>60000]
# Out:
#            Country Name  High-technology exports (% of manufactured exports)  \
# 68               France                                             25.920
# 73              Germany                                             15.778
# 89                India                                              9.008
# 96                Italy                                              7.505
# 98                Japan                                             17.268
# 104         Korea, Rep.                                             36.347
# 161  Russian Federation                                             10.963
# 206      United Kingdom                                             22.643
# 207       United States                                             18.896
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 68                        117814412441.000                      98279.000
# 73                        210082307180.000                      75236.000
# 89                         20273090235.000                     323970.000
# 96                         32581025234.000                      42580.000
# 98                        111020443595.000                     183657.000
# 104                       192789656676.000                     199476.000
# 161                        10183007833.000                      75081.000
# 206                        76926541023.000                      94915.000
# 207                       156365524736.000                     464786.000
#
#      Trademark applications, direct resident  \
# 68                                 90581.000
# 73                                 65686.000
# 89                                297750.000
# 96                                 37320.000
# 98                                145269.000
# 104                               170541.000
# 161                                49132.000
# 206                                66833.000
# 207                               342150.000
#
#      Trademark applications, direct nonresident  \
# 68                                     7698.000
# 73                                     9550.000
# 89                                    26220.000
# 96                                     5260.000
# 98                                    38388.000
# 104                                   28935.000
# 161                                   25949.000
# 206                                   28082.000
# 207                                  122636.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 68                        14303.000                           1919.000
# 73                        46617.000                          21281.000
# 89                        16289.000                          33766.000
# 96                         8921.000                            900.000
# 98                       253630.000                          59937.000
# 104                      162561.000                          47431.000
# 161                       24926.000                          13031.000
# 206                       12865.000                           8076.000
# 207                      285095.000                         312046.000
#
#      Scientific and technical journal articles  \
# 68                                   66352.180
# 73                                  104396.120
# 89                                  135787.790
# 96                                   71240.280
# 98                                   98792.500
# 104                                  66376.170
# 161                                  81579.360
# 206                                  97680.900
# 207                                 422807.710
#
#      Research and development expenditure (% of GDP)
# 68                                             2.200
# 73                                             3.094
# 89                                             0.650
# 96                                             1.399
# 98                                             3.265
# 104                                            4.810
# 161                                            0.990
# 206                                            1.724
# 207                                            2.838

# %%
columns=st_data_2009_clean.columns
for i in range(1,len(columns)):
    fig=plt.figure(figsize=(10,5))
    sns.boxplot(x=st_data_2009_clean[columns[i]])

# %%
trade_apps_res_max=st_data_2009_clean['Trademark applications, direct resident'].max()

# %%
st_data_2018_clean[st_data_2018_clean['Trademark applications, direct resident']>200000]
# Out:
#       Country Name  High-technology exports (% of manufactured exports)  \
# 89           India                                              9.008
# 207  United States                                             18.896
#
#      High-technology exports (current US$)  Trademark applications, total  \
# 89                         20273090235.000                     323970.000
# 207                       156365524736.000                     464786.000
#
#      Trademark applications, direct resident  \
# 89                                297750.000
# 207                               342150.000
#
#      Trademark applications, direct nonresident  \
# 89                                    26220.000
# 207                                  122636.000
#
#      Patent applications, residents  Patent applications, nonresidents  \
# 89                        16289.000                          33766.000
# 207                      285095.000                         312046.000
#
#      Scientific and technical journal articles  \
# 89                                  135787.790
# 207                                 422807.710
#
#      Research and development expenditure (% of GDP)
# 89                                             0.650
# 207                                            2.838

# %% [markdown]
# ## Exploring Relationships

# %% [markdown]
# ### Correlations

# %%
st_data_18_nocountry=st_data_2018_clean.drop('Country Name', axis=1)

# %%
st_data_18_nocountry.corr(method='pearson').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_a751c_row0_col0, #T_a751c_row1_col1, #T_a751c_row2_col2, #T_a751c_row3_col3, #T_a751c_row4_col4, #T_a751c_row5_col5, #T_a751c_row6_col6, #T_a751c_row7_col7, #T_a751c_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_a751c_row0_col1 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_a751c_row0_col2 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_a751c_row0_col3, #T_a751c_row8_col1, #T_a751c_row8_col6 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_a751c_row0_col4, #T_a751c_row8_col7 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_a751c_row0_col5, #T_a751c_row0_col6, #T_a751c_row0_col7, #T_a751c_row4_col8, #T_a751c_row6_col0, #T_a751c_row6_col1, #T_a751c_row8_col2, #T_a751c_row8_col3, #T_a751c_row8_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_a751c_row0_col8 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_a751c_row1_col0 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_a751c_row1_col2, #T_a751c_row1_col3, #T_a751c_row1_col7 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_a751c_row1_col4 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_a751c_row1_col5 {
#   background-color: #1f988b;
#   color: #f1f1f1;
# }
# #T_a751c_row1_col6 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_a751c_row1_col8 {
#   background-color: #277f8e;
#   color: #f1f1f1;
# }
# #T_a751c_row2_col0 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_a751c_row2_col1 {
#   background-color: #3e4a89;
#   color: #f1f1f1;
# }
# #T_a751c_row2_col3, #T_a751c_row3_col2 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_a751c_row2_col4 {
#   background-color: #9dd93b;
#   color: #000000;
# }
# #T_a751c_row2_col5 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_a751c_row2_col6 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_a751c_row2_col7 {
#   background-color: #a5db36;
#   color: #000000;
# }
# #T_a751c_row2_col8 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_a751c_row3_col0 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_a751c_row3_col1 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_a751c_row3_col4, #T_a751c_row5_col6 {
#   background-color: #69cd5b;
#   color: #000000;
# }
# #T_a751c_row3_col5 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_a751c_row3_col6 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_a751c_row3_col7, #T_a751c_row7_col3 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_a751c_row3_col8 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_a751c_row4_col0 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_a751c_row4_col1 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_a751c_row4_col2 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_a751c_row4_col3 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_a751c_row4_col5, #T_a751c_row5_col2, #T_a751c_row5_col7, #T_a751c_row6_col3 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_a751c_row4_col6, #T_a751c_row6_col4 {
#   background-color: #cae11f;
#   color: #000000;
# }
# #T_a751c_row4_col7 {
#   background-color: #b0dd2f;
#   color: #000000;
# }
# #T_a751c_row5_col0 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_a751c_row5_col1 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_a751c_row5_col3 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_a751c_row5_col4 {
#   background-color: #56c667;
#   color: #000000;
# }
# #T_a751c_row5_col8 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_a751c_row6_col2 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_a751c_row6_col5 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_a751c_row6_col7 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_a751c_row6_col8 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_a751c_row7_col0 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_a751c_row7_col1 {
#   background-color: #3f4889;
#   color: #f1f1f1;
# }
# #T_a751c_row7_col2 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_a751c_row7_col4 {
#   background-color: #b2dd2d;
#   color: #000000;
# }
# #T_a751c_row7_col5 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_a751c_row7_col6 {
#   background-color: #c0df25;
#   color: #000000;
# }
# #T_a751c_row7_col8 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_a751c_row8_col0 {
#   background-color: #21908d;
#   color: #f1f1f1;
# }
# #T_a751c_row8_col5 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a751c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a751c_level0_col0" class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th id="T_a751c_level0_col1" class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th id="T_a751c_level0_col2" class="col_heading level0 col2" >Trademark applications, total</th>
#       <th id="T_a751c_level0_col3" class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th id="T_a751c_level0_col4" class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th id="T_a751c_level0_col5" class="col_heading level0 col5" >Patent applications, residents</th>
#       <th id="T_a751c_level0_col6" class="col_heading level0 col6" >Patent applications, nonresidents</th>
#       <th id="T_a751c_level0_col7" class="col_heading level0 col7" >Scientific and technical journal articles</th>
#       <th id="T_a751c_level0_col8" class="col_heading level0 col8" >Research and development expenditure (% of GDP)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a751c_level0_row0" class="row_heading level0 row0" >High-technology exports (% of manufactured exports)</th>
#       <td id="T_a751c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a751c_row0_col1" class="data row0 col1" >0.580170</td>
#       <td id="T_a751c_row0_col2" class="data row0 col2" >0.317002</td>
#       <td id="T_a751c_row0_col3" class="data row0 col3" >0.311593</td>
#       <td id="T_a751c_row0_col4" class="data row0 col4" >0.292695</td>
#       <td id="T_a751c_row0_col5" class="data row0 col5" >0.346438</td>
#       <td id="T_a751c_row0_col6" class="data row0 col6" >0.226806</td>
#       <td id="T_a751c_row0_col7" class="data row0 col7" >0.265684</td>
#       <td id="T_a751c_row0_col8" class="data row0 col8" >0.612370</td>
#     </tr>
#     <tr>
#       <th id="T_a751c_level0_row1" class="row_heading level0 row1" >High-technology exports (current US$)</th>
#       <td id="T_a751c_row1_col0" class="data row1 col0" >0.580170</td>
#       <td id="T_a751c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a751c_row1_col2" class="data row1 col2" >0.641144</td>
#       <td id="T_a751c_row1_col3" class="data row1 col3" >0.638493</td>
#       <td id="T_a751c_row1_col4" class="data row1 col4" >0.561467</td>
#       <td id="T_a751c_row1_col5" class="data row1 col5" >0.694110</td>
#       <td id="T_a751c_row1_col6" class="data row1 col6" >0.536050</td>
#       <td id="T_a751c_row1_col7" class="data row1 col7" >0.635776</td>
#       <td id="T_a751c_row1_col8" class="data row1 col8" >0.564181</td>
#     </tr>
#     <tr>
#       <th id="T_a751c_level0_row2" class="row_heading level0 row2" >Trademark applications, total</th>
#       <td id="T_a751c_row2_col0" class="data row2 col0" >0.317002</td>
#       <td id="T_a751c_row2_col1" class="data row2 col1" >0.641144</td>
#       <td id="T_a751c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a751c_row2_col3" class="data row2 col3" >0.992243</td>
#       <td id="T_a751c_row2_col4" class="data row2 col4" >0.889062</td>
#       <td id="T_a751c_row2_col5" class="data row2 col5" >0.775550</td>
#       <td id="T_a751c_row2_col6" class="data row2 col6" >0.836150</td>
#       <td id="T_a751c_row2_col7" class="data row2 col7" >0.899688</td>
#       <td id="T_a751c_row2_col8" class="data row2 col8" >0.269173</td>
#     </tr>
#     <tr>
#       <th id="T_a751c_level0_row3" class="row_heading level0 row3" >Trademark applications, direct resident</th>
#       <td id="T_a751c_row3_col0" class="data row3 col0" >0.311593</td>
#       <td id="T_a751c_row3_col1" class="data row3 col1" >0.63

# %%
st_data_18_nocountry.corr(method='spearman').style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_0f22d_row0_col0, #T_0f22d_row1_col1, #T_0f22d_row2_col2, #T_0f22d_row3_col3, #T_0f22d_row4_col4, #T_0f22d_row5_col5, #T_0f22d_row6_col6, #T_0f22d_row7_col7, #T_0f22d_row8_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_0f22d_row0_col1, #T_0f22d_row8_col1 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_0f22d_row0_col2 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_0f22d_row0_col3 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_0f22d_row0_col4 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_0f22d_row0_col5, #T_0f22d_row0_col6, #T_0f22d_row0_col7, #T_0f22d_row4_col0, #T_0f22d_row4_col1, #T_0f22d_row4_col8, #T_0f22d_row8_col2, #T_0f22d_row8_col3, #T_0f22d_row8_col4 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_0f22d_row0_col8, #T_0f22d_row7_col6 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_0f22d_row1_col0, #T_0f22d_row2_col5 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_0f22d_row1_col2 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_0f22d_row1_col3, #T_0f22d_row5_col1 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_0f22d_row1_col4 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_0f22d_row1_col5, #T_0f22d_row2_col7, #T_0f22d_row5_col4 {
#   background-color: #1fa187;
#   color: #f1f1f1;
# }
# #T_0f22d_row1_col6 {
#   background-color: #2d718e;
#   color: #f1f1f1;
# }
# #T_0f22d_row1_col7, #T_0f22d_row3_col6 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_0f22d_row1_col8, #T_0f22d_row3_col5 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_0f22d_row2_col0 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_0f22d_row2_col1 {
#   background-color: #2c728e;
#   color: #f1f1f1;
# }
# #T_0f22d_row2_col3 {
#   background-color: #d5e21a;
#   color: #000000;
# }
# #T_0f22d_row2_col4 {
#   background-color: #a8db34;
#   color: #000000;
# }
# #T_0f22d_row2_col6, #T_0f22d_row7_col3 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_0f22d_row2_col8 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_0f22d_row3_col0 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_0f22d_row3_col1 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_0f22d_row3_col2 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_0f22d_row3_col4 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_0f22d_row3_col7, #T_0f22d_row5_col2 {
#   background-color: #50c46a;
#   color: #000000;
# }
# #T_0f22d_row3_col8 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_0f22d_row4_col2 {
#   background-color: #95d840;
#   color: #000000;
# }
# #T_0f22d_row4_col3, #T_0f22d_row7_col8 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_0f22d_row4_col5 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_0f22d_row4_col6 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_0f22d_row4_col7 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_0f22d_row5_col0 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_0f22d_row5_col3, #T_0f22d_row7_col2 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_0f22d_row5_col6 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_0f22d_row5_col7 {
#   background-color: #70cf57;
#   color: #000000;
# }
# #T_0f22d_row5_col8 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_0f22d_row6_col0 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_0f22d_row6_col1 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_0f22d_row6_col2 {
#   background-color: #86d549;
#   color: #000000;
# }
# #T_0f22d_row6_col3 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_0f22d_row6_col4, #T_0f22d_row7_col1 {
#   background-color: #84d44b;
#   color: #000000;
# }
# #T_0f22d_row6_col5 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_0f22d_row6_col7 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_0f22d_row6_col8 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_0f22d_row7_col0 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_0f22d_row7_col4 {
#   background-color: #1f958b;
#   color: #f1f1f1;
# }
# #T_0f22d_row7_col5 {
#   background-color: #8bd646;
#   color: #000000;
# }
# #T_0f22d_row8_col0 {
#   background-color: #1e9c89;
#   color: #f1f1f1;
# }
# #T_0f22d_row8_col5, #T_0f22d_row8_col7 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_0f22d_row8_col6 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0f22d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f22d_level0_col0" class="col_heading level0 col0" >High-technology exports (% of manufactured exports)</th>
#       <th id="T_0f22d_level0_col1" class="col_heading level0 col1" >High-technology exports (current US$)</th>
#       <th id="T_0f22d_level0_col2" class="col_heading level0 col2" >Trademark applications, total</th>
#       <th id="T_0f22d_level0_col3" class="col_heading level0 col3" >Trademark applications, direct resident</th>
#       <th id="T_0f22d_level0_col4" class="col_heading level0 col4" >Trademark applications, direct nonresident</th>
#       <th id="T_0f22d_level0_col5" class="col_heading level0 col5" >Patent applications, residents</th>
#       <th id="T_0f22d_level0_col6" class="col_heading level0 col6" >Patent applications, nonresidents</th>
#       <th id="T_0f22d_level0_col7" class="col_heading level0 col7" >Scientific and technical journal articles</th>
#       <th id="T_0f22d_level0_col8" class="col_heading level0 col8" >Research and development expenditure (% of GDP)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f22d_level0_row0" class="row_heading level0 row0" >High-technology exports (% of manufactured exports)</th>
#       <td id="T_0f22d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0f22d_row0_col1" class="data row0 col1" >0.721448</td>
#       <td id="T_0f22d_row0_col2" class="data row0 col2" >0.273756</td>
#       <td id="T_0f22d_row0_col3" class="data row0 col3" >0.352127</td>
#       <td id="T_0f22d_row0_col4" class="data row0 col4" >0.196380</td>
#       <td id="T_0f22d_row0_col5" class="data row0 col5" >0.384226</td>
#       <td id="T_0f22d_row0_col6" class="data row0 col6" >0.290776</td>
#       <td id="T_0f22d_row0_col7" class="data row0 col7" >0.510045</td>
#       <td id="T_0f22d_row0_col8" class="data row0 col8" >0.636471</td>
#     </tr>
#     <tr>
#       <th id="T_0f22d_level0_row1" class="row_heading level0 row1" >High-technology exports (current US$)</th>
#       <td id="T_0f22d_row1_col0" class="data row1 col0" >0.721448</td>
#       <td id="T_0f22d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0f22d_row1_col2" class="data row1 col2" >0.605882</td>
#       <td id="T_0f22d_row1_col3" class="data row1 col3" >0.718733</td>
#       <td id="T_0f22d_row1_col4" class="data row1 col4" >0.368959</td>
#       <td id="T_0f22d_row1_col5" class="data row1 col5" >0.737273</td>
#       <td id="T_0f22d_row1_col6" class="data row1 col6" >0.551641</td>
#       <td id="T_0f22d_row1_col7" class="data row1 col7" >0.882262</td>
#       <td id="T_0f22d_row1_col8" class="data row1 col8" >0.719548</td>
#     </tr>
#     <tr>
#       <th id="T_0f22d_level0_row2" class="row_heading level0 row2" >Trademark applications, total</th>
#       <td id="T_0f22d_row2_col0" class="data row2 col0" >0.273756</td>
#       <td id="T_0f22d_row2_col1" class="data row2 col1" >0.605882</td>
#       <td id="T_0f22d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0f22d_row2_col3" class="data row2 col3" >0.955928</td>
#       <td id="T_0f22d_row2_col4" class="data row2 col4" >0.877828</td>
#       <td id="T_0f22d_row2_col5" class="data row2 col5" >0.786732</td>
#       <td id="T_0f22d_row2_col6" class="data row2 col6" >0.861060</td>
#       <td id="T_0f22d_row2_col7" class="data row2 col7" >0.789502</td>
#       <td id="T_0f22d_row2_col8" class="data row2 col8" >0.229502</td>
#     </tr>
#     <tr>
#       <th id="T_0f22d_level0_row3" class="row_heading level0 row3" >Trademark applications, direct resident</th>
#       <td id="T_0f22d_row3_col0" class="data row3 col0" >0.352127</td>
#       <td id="T_0f22d_row3_col1" class="data row3 col1" >0.718733</td>
#       <td id="T_0f22d_row3_col2" class="data row3 col2" >0.955928</td>
#       <td id="T_0f2

# %%
st_data_2018_clean.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, nonresidents')
# Out:
# <Axes: xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
st_data_2018_nonUS = st_data_2018_clean[st_data_2018_clean['Country Name']!='United States']

# %%
st_data_2018_nonUS.plot.scatter(x='Scientific and technical journal articles', y='Patent applications, nonresidents')
# Out:
# <Axes: xlabel='Scientific and technical journal articles', ylabel='Patent applications, nonresidents'>

# %%
st_data_2018_clean.plot.scatter(x='Research and development expenditure (% of GDP)', y='High-technology exports (current US$)')
# Out:
# <Axes: xlabel='Research and development expenditure (% of GDP)', ylabel='High-technology exports (current US$)'>

# %%
import scipy.stats as stats

# %%
a=st_data_2009_clean['Patent applications, residents']
b=st_data_2018_clean['Patent applications, residents']
stats.ttest_ind(a,b)
# Out:
# TtestResult(statistic=0.17093628150351461, pvalue=0.8646028361752646, df=105.0)

# %%
a=st_data_2009_clean[columns[i]]
b=st_data_2018_clean[columns[i]]

# %%
for i in range(1,len(columns)):
    a=st_data_2009_clean[columns[i]]
    b=st_data_2018_clean[columns[i]]
    print(columns[i])
    statistic, pvalue = stats.ttest_ind(a,b)
    print("Statistic: %s p-value: %s" %(statistic, pvalue))
    if pvalue < 0.05:
        print("Significant")
    else:
        print("Not Significant")
# Out:
# High-technology exports (% of manufactured exports)
# Statistic: 1.5178124850425097 p-value: 0.13206686889029143
# Not Significant
# High-technology exports (current US$)
# Statistic: 0.12265583290103693 p-value: 0.902614099731734
# Not Significant
# Trademark applications, total
# Statistic: 0.2704033385824462 p-value: 0.7873807591420726
# Not Significant
# Trademark applications, direct resident
# Statistic: 0.38774421679415133 p-value: 0.6989902537733603
# Not Significant
# Trademark applications, direct nonresident
# Statistic: -0.48589263440463604 p-value: 0.628055750890876
# Not Significant
# Patent applications, residents
# Statistic: 0.17093628150351461 p-value: 0.8646028361752646
# Not Significant
# Patent applications, nonresidents
# Statistic: -0.04471790792368344 p-value: 0.9644170934929569
# Not Significant
# Scientific and technical journal articles
# Statistic: -0.006105403997445266 p-value: 0.9951402075104707
# Not Significant
# Research and development expenditure (% of GDP)
# Statistic: -0.27962305489587164 p-value: 0.7803167965750051
# Not Significant

# %%
st_data_2009.head()
# Out:
#      Country Name  High-technology exports (% of manufactured exports)  \
# 0     Afghanistan                                                NaN
# 1         Albania                                              1.328
# 2         Algeria                                              0.654
# 3  American Samoa                                                NaN
# 4         Andorra                                             12.192
#
#    High-technology exports (current US$)  Trademark applications, total  \
# 0                                    NaN                            NaN
# 1                           10128935.000                       3456.000
# 2                            4616076.000                       5345.000
# 3                                    NaN                            NaN
# 4                           10402350.000                        785.000
#
#    Trademark applications, direct resident  \
# 0                                      NaN
# 1                                  213.000
# 2                                      NaN
# 3                                      NaN
# 4                                  243.000
#
#    Trademark applications, direct nonresident  Patent applications, residents  \
# 0                                         NaN                             NaN
# 1                                    3243.000                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                     542.000                             NaN
#
#    Patent applications, nonresidents  \
# 0                                NaN
# 1                            361.000
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    Scientific and technical journal articles  \
# 0                                     26.300
# 1                                     70.350
# 2                                   2135.320
# 3                                        NaN
# 4                                      2.550
#
#    Research and development expenditure (% of GDP)
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
